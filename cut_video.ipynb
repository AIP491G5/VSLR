# %%
import cv2
import pandas as pd
import numpy as np
import os
import sys
import absl.logging
from detector import MediaPipeProcessor
from config import Config
# ---------- Khởi tạo model ----------
model = MediaPipeProcessor(Config())
vid_not_kept = []
df_video = pd.DataFrame()

# %%
def moved(curr_kps: np.ndarray, ref_kps: np.ndarray, threshold=0.36) -> bool:
    """
    Trả về True nếu có ít nhất một phần tử của curr_kps khác ref_kps
    hơn ngưỡng threshold (normalized).
    """
    # So sánh độ chênh tuyệt đối từng chiều
    diffs = np.abs(curr_kps - ref_kps)
    return np.any(diffs > threshold)

# %%
def filter_video(file_name, src, dst):
    cap = cv2.VideoCapture(src)
    # 1. Đọc khung đầu tiên, lấy keypoints làm reference
    ret, frame0 = cap.read()
    if not ret:
        print(f"✘ Không đọc được khung đầu của {src}")
        cap.release()
        return

    image0 = cv2.cvtColor(frame0, cv2.COLOR_BGR2RGB)
    _, ref_res = model.process_frame(image0)
    ref_kps = model.extract_keypoints(ref_res)

    fps = cap.get(cv2.CAP_PROP_FPS) or 30
    w   = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    h   = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    out = cv2.VideoWriter(dst, cv2.VideoWriter_fourcc(*'mp4v'), fps, (w, h))
    frame = 1
    kept = dropped = 0
    while True:
        ok, frame = cap.read()
        if not ok:
            break

        image_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        _, res = model.process_frame(image_rgb)
        
        if res.pose_landmarks:
            kpts = model.extract_keypoints(res)
            if moved(kpts, ref_kps):
                out.write(frame); kept += 1
                frame += 1
                continue

        dropped += 1
        frame += 1
    if kept == 0:
        print(f"✘ Không giữ khung nào từ video: {src}")
        vid_not_kept.append(src)
        os.remove(dst)  # xóa file video đã tạo
    cap.release()
    out.release()
    print(f"✔ Giữ {kept} khung, loại {dropped} khung – video lưu: {dst}")
    return {'video': file_name, 'raw frame count': frame, 'filter frame count': kept}

# %%
def main():
    video_data = []
    files_name = 'top50_daily.csv'
    df = pd.read_csv(files_name)
    for i in df.index:
        files = [x.strip() for x in df.loc[i, "VIDEO"].split(",")]
        print(f"Đang xử lý video gloss {i}: {files}")
        for file in files:
            print(f"Đang xử lý video: {file}")
            src = os.path.join('Dataset', 'Video', file)
            dst = os.path.join('data', 'Video', file)
            if not os.path.exists(src):
                print(f"✘ Không tìm thấy video: {src}")
                continue
            if not os.path.exists(os.path.dirname(dst)):
                os.makedirs(os.path.dirname(dst))
            data = filter_video(file, src, dst)
            video_data.append(data)
            print(f"Video đã lưu tại: {dst}")
            print("-" * 50)
            print("\n")
    print(len(vid_not_kept), "video không giữ khung nào:", vid_not_kept)
    df_video = pd.DataFrame(video_data)
if __name__ == '__main__':
    main()
# Out:
# Đang xử lý video gloss 0: ['W03373B.mp4', 'W03373N.mp4', 'W03373T.mp4', 'W03450B.mp4', 'W03450T.mp4', 'W03450N.mp4']
# Đang xử lý video: W03373B.mp4
# ✔ Giữ 55 khung, loại 71 khung – video lưu: data/Video/W03373B.mp4
# Video đã lưu tại: data/Video/W03373B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03373N.mp4
# ✔ Giữ 47 khung, loại 32 khung – video lưu: data/Video/W03373N.mp4
# Video đã lưu tại: data/Video/W03373N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03373T.mp4
# ✔ Giữ 123 khung, loại 3 khung – video lưu: data/Video/W03373T.mp4
# Video đã lưu tại: data/Video/W03373T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03450B.mp4
# ✔ Giữ 73 khung, loại 28 khung – video lưu: data/Video/W03450B.mp4
# Video đã lưu tại: data/Video/W03450B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03450T.mp4
# ✔ Giữ 72 khung, loại 41 khung – video lưu: data/Video/W03450T.mp4
# Video đã lưu tại: data/Video/W03450T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03450N.mp4
# ✔ Giữ 67 khung, loại 46 khung – video lưu: data/Video/W03450N.mp4
# Video đã lưu tại: data/Video/W03450N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 1: ['W01122B.mp4', 'W01122T.mp4', 'W01122N.mp4', 'W01122.mp4']
# Đang xử lý video: W01122B.mp4
# ✔ Giữ 32 khung, loại 34 khung – video lưu: data/Video/W01122B.mp4
# Video đã lưu tại: data/Video/W01122B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W01122T.mp4
# ✔ Giữ 49 khung, loại 38 khung – video lưu: data/Video/W01122T.mp4
# Video đã lưu tại: data/Video/W01122T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W01122N.mp4
# ✔ Giữ 50 khung, loại 37 khung – video lưu: data/Video/W01122N.mp4
# Video đã lưu tại: data/Video/W01122N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W01122.mp4
# ✔ Giữ 45 khung, loại 270 khung – video lưu: data/Video/W01122.mp4
# Video đã lưu tại: data/Video/W01122.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 2: ['W03175N.mp4', 'W03175T.mp4', 'W03175B.mp4', 'W03175.mp4']
# Đang xử lý video: W03175N.mp4
# ✔ Giữ 54 khung, loại 69 khung – video lưu: data/Video/W03175N.mp4
# Video đã lưu tại: data/Video/W03175N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03175T.mp4
# ✔ Giữ 46 khung, loại 76 khung – video lưu: data/Video/W03175T.mp4
# Video đã lưu tại: data/Video/W03175T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03175B.mp4
# ✔ Giữ 49 khung, loại 73 khung – video lưu: data/Video/W03175B.mp4
# Video đã lưu tại: data/Video/W03175B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03175.mp4
# ✔ Giữ 45 khung, loại 35 khung – video lưu: data/Video/W03175.mp4
# Video đã lưu tại: data/Video/W03175.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 3: ['D0156N.mp4', 'D0156B.mp4', 'D0156.mp4', 'D0156T.mp4']
# Đang xử lý video: D0156N.mp4
# ✔ Giữ 67 khung, loại 71 khung – video lưu: data/Video/D0156N.mp4
# Video đã lưu tại: data/Video/D0156N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: D0156B.mp4
# ✔ Giữ 44 khung, loại 65 khung – video lưu: data/Video/D0156B.mp4
# Video đã lưu tại: data/Video/D0156B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: D0156.mp4
# ✔ Giữ 136 khung, loại 26 khung – video lưu: data/Video/D0156.mp4
# Video đã lưu tại: data/Video/D0156.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: D0156T.mp4
# ✔ Giữ 66 khung, loại 72 khung – video lưu: data/Video/D0156T.mp4
# Video đã lưu tại: data/Video/D0156T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 4: ['W03732T.mp4', 'W03732.mp4', 'W03732N.mp4', 'W03732B.mp4']
# Đang xử lý video: W03732T.mp4
# ✔ Giữ 71 khung, loại 34 khung – video lưu: data/Video/W03732T.mp4
# Video đã lưu tại: data/Video/W03732T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03732.mp4
# ✔ Giữ 66 khung, loại 81 khung – video lưu: data/Video/W03732.mp4
# Video đã lưu tại: data/Video/W03732.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03732N.mp4
# ✔ Giữ 37 khung, loại 51 khung – video lưu: data/Video/W03732N.mp4
# Video đã lưu tại: data/Video/W03732N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03732B.mp4
# ✔ Giữ 62 khung, loại 43 khung – video lưu: data/Video/W03732B.mp4
# Video đã lưu tại: data/Video/W03732B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 5: ['W00328N.mp4', 'W00328T.mp4', 'W00328B.mp4']
# Đang xử lý video: W00328N.mp4
# ✔ Giữ 60 khung, loại 74 khung – video lưu: data/Video/W00328N.mp4
# Video đã lưu tại: data/Video/W00328N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00328T.mp4
# ✔ Giữ 45 khung, loại 69 khung – video lưu: data/Video/W00328T.mp4
# Video đã lưu tại: data/Video/W00328T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00328B.mp4
# ✔ Giữ 56 khung, loại 88 khung – video lưu: data/Video/W00328B.mp4
# Video đã lưu tại: data/Video/W00328B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 6: ['W00286N.mp4', 'W00286B.mp4', 'W00286T.mp4']
# Đang xử lý video: W00286N.mp4
# ✔ Giữ 33 khung, loại 84 khung – video lưu: data/Video/W00286N.mp4
# Video đã lưu tại: data/Video/W00286N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00286B.mp4
# ✔ Giữ 105 khung, loại 0 khung – video lưu: data/Video/W00286B.mp4
# Video đã lưu tại: data/Video/W00286B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00286T.mp4
# ✔ Giữ 34 khung, loại 83 khung – video lưu: data/Video/W00286T.mp4
# Video đã lưu tại: data/Video/W00286T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 7: ['W03037T.mp4', 'W03037B.mp4', 'W03037N.mp4']
# Đang xử lý video: W03037T.mp4
# ✔ Giữ 75 khung, loại 17 khung – video lưu: data/Video/W03037T.mp4
# Video đã lưu tại: data/Video/W03037T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03037B.mp4
# ✔ Giữ 126 khung, loại 6 khung – video lưu: data/Video/W03037B.mp4
# Video đã lưu tại: data/Video/W03037B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03037N.mp4
# ✔ Giữ 80 khung, loại 12 khung – video lưu: data/Video/W03037N.mp4
# Video đã lưu tại: data/Video/W03037N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 8: ['W03038N.mp4', 'W03038T.mp4', 'W03038B.mp4']
# Đang xử lý video: W03038N.mp4
# ✔ Giữ 64 khung, loại 12 khung – video lưu: data/Video/W03038N.mp4
# Video đã lưu tại: data/Video/W03038N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03038T.mp4
# ✔ Giữ 65 khung, loại 11 khung – video lưu: data/Video/W03038T.mp4
# Video đã lưu tại: data/Video/W03038T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03038B.mp4
# ✔ Giữ 83 khung, loại 7 khung – video lưu: data/Video/W03038B.mp4
# Video đã lưu tại: data/Video/W03038B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 9: ['W03036T.mp4', 'W03036B.mp4', 'W03036N.mp4']
# Đang xử lý video: W03036T.mp4
# ✔ Giữ 75 khung, loại 5 khung – video lưu: data/Video/W03036T.mp4
# Video đã lưu tại: data/Video/W03036T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03036B.mp4
# ✔ Giữ 112 khung, loại 1 khung – video lưu: data/Video/W03036B.mp4
# Video đã lưu tại: data/Video/W03036B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03036N.mp4
# ✔ Giữ 72 khung, loại 8 khung – video lưu: data/Video/W03036N.mp4
# Video đã lưu tại: data/Video/W03036N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 10: ['W00304N.mp4', 'W00304B.mp4', 'W00304T.mp4']
# Đang xử lý video: W00304N.mp4
# ✔ Giữ 46 khung, loại 97 khung – video lưu: data/Video/W00304N.mp4
# Video đã lưu tại: data/Video/W00304N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00304B.mp4
# ✔ Giữ 70 khung, loại 20 khung – video lưu: data/Video/W00304B.mp4
# Video đã lưu tại: data/Video/W00304B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00304T.mp4
# ✔ Giữ 46 khung, loại 97 khung – video lưu: data/Video/W00304T.mp4
# Video đã lưu tại: data/Video/W00304T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 11: ['W03011B.mp4', 'W03011T.mp4', 'W03011N.mp4']
# Đang xử lý video: W03011B.mp4
# ✔ Giữ 35 khung, loại 45 khung – video lưu: data/Video/W03011B.mp4
# Video đã lưu tại: data/Video/W03011B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03011T.mp4
# ✔ Giữ 90 khung, loại 41 khung – video lưu: data/Video/W03011T.mp4
# Video đã lưu tại: data/Video/W03011T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03011N.mp4
# ✔ Giữ 66 khung, loại 32 khung – video lưu: data/Video/W03011N.mp4
# Video đã lưu tại: data/Video/W03011N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 12: ['W00326B.mp4', 'W00326T.mp4', 'W00326N.mp4']
# Đang xử lý video: W00326B.mp4
# ✔ Giữ 68 khung, loại 43 khung – video lưu: data/Video/W00326B.mp4
# Video đã lưu tại: data/Video/W00326B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00326T.mp4
# ✔ Giữ 40 khung, loại 30 khung – video lưu: data/Video/W00326T.mp4
# Video đã lưu tại: data/Video/W00326T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00326N.mp4
# ✔ Giữ 40 khung, loại 30 khung – video lưu: data/Video/W00326N.mp4
# Video đã lưu tại: data/Video/W00326N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 13: ['W00459T.mp4', 'W00459N.mp4', 'W00459B.mp4']
# Đang xử lý video: W00459T.mp4
# ✔ Giữ 53 khung, loại 37 khung – video lưu: data/Video/W00459T.mp4
# Video đã lưu tại: data/Video/W00459T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00459N.mp4
# ✔ Giữ 53 khung, loại 37 khung – video lưu: data/Video/W00459N.mp4
# Video đã lưu tại: data/Video/W00459N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00459B.mp4
# ✔ Giữ 87 khung, loại 33 khung – video lưu: data/Video/W00459B.mp4
# Video đã lưu tại: data/Video/W00459B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 14: ['W00336T.mp4', 'W00336B.mp4', 'W00336N.mp4']
# Đang xử lý video: W00336T.mp4
# ✔ Giữ 55 khung, loại 58 khung – video lưu: data/Video/W00336T.mp4
# Video đã lưu tại: data/Video/W00336T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00336B.mp4
# ✔ Giữ 80 khung, loại 71 khung – video lưu: data/Video/W00336B.mp4
# Video đã lưu tại: data/Video/W00336B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00336N.mp4
# ✔ Giữ 55 khung, loại 58 khung – video lưu: data/Video/W00336N.mp4
# Video đã lưu tại: data/Video/W00336N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 15: ['W03040B.mp4', 'W03040N.mp4', 'W03040T.mp4']
# Đang xử lý video: W03040B.mp4
# ✔ Giữ 43 khung, loại 112 khung – video lưu: data/Video/W03040B.mp4
# Video đã lưu tại: data/Video/W03040B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03040N.mp4
# ✔ Giữ 73 khung, loại 29 khung – video lưu: data/Video/W03040N.mp4
# Video đã lưu tại: data/Video/W03040N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03040T.mp4
# ✔ Giữ 155 khung, loại 0 khung – video lưu: data/Video/W03040T.mp4
# Video đã lưu tại: data/Video/W03040T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 16: ['W02956N.mp4', 'W02956T.mp4', 'W02956B.mp4']
# Đang xử lý video: W02956N.mp4
# ✔ Giữ 64 khung, loại 2 khung – video lưu: data/Video/W02956N.mp4
# Video đã lưu tại: data/Video/W02956N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02956T.mp4
# ✔ Giữ 52 khung, loại 14 khung – video lưu: data/Video/W02956T.mp4
# Video đã lưu tại: data/Video/W02956T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02956B.mp4
# ✔ Giữ 92 khung, loại 17 khung – video lưu: data/Video/W02956B.mp4
# Video đã lưu tại: data/Video/W02956B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 17: ['W00337B.mp4', 'W00337T.mp4', 'W00337N.mp4']
# Đang xử lý video: W00337B.mp4
# ✔ Giữ 86 khung, loại 61 khung – video lưu: data/Video/W00337B.mp4
# Video đã lưu tại: data/Video/W00337B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00337T.mp4
# ✔ Giữ 59 khung, loại 133 khung – video lưu: data/Video/W00337T.mp4
# Video đã lưu tại: data/Video/W00337T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00337N.mp4
# ✔ Giữ 61 khung, loại 131 khung – video lưu: data/Video/W00337N.mp4
# Video đã lưu tại: data/Video/W00337N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 18: ['W00341T.mp4', 'W00341N.mp4', 'W00341B.mp4']
# Đang xử lý video: W00341T.mp4
# ✔ Giữ 67 khung, loại 62 khung – video lưu: data/Video/W00341T.mp4
# Video đã lưu tại: data/Video/W00341T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00341N.mp4
# ✔ Giữ 67 khung, loại 62 khung – video lưu: data/Video/W00341N.mp4
# Video đã lưu tại: data/Video/W00341N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00341B.mp4
# ✔ Giữ 72 khung, loại 50 khung – video lưu: data/Video/W00341B.mp4
# Video đã lưu tại: data/Video/W00341B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 19: ['W00338B.mp4', 'W00338N.mp4', 'W00338T.mp4']
# Đang xử lý video: W00338B.mp4
# ✔ Giữ 80 khung, loại 52 khung – video lưu: data/Video/W00338B.mp4
# Video đã lưu tại: data/Video/W00338B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00338N.mp4
# ✔ Giữ 70 khung, loại 88 khung – video lưu: data/Video/W00338N.mp4
# Video đã lưu tại: data/Video/W00338N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00338T.mp4
# ✔ Giữ 70 khung, loại 88 khung – video lưu: data/Video/W00338T.mp4
# Video đã lưu tại: data/Video/W00338T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 20: ['W02953N.mp4', 'W02953B.mp4', 'W02953T.mp4']
# Đang xử lý video: W02953N.mp4
# ✔ Giữ 58 khung, loại 34 khung – video lưu: data/Video/W02953N.mp4
# Video đã lưu tại: data/Video/W02953N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02953B.mp4
# ✔ Giữ 131 khung, loại 3 khung – video lưu: data/Video/W02953B.mp4
# Video đã lưu tại: data/Video/W02953B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02953T.mp4
# ✔ Giữ 77 khung, loại 15 khung – video lưu: data/Video/W02953T.mp4
# Video đã lưu tại: data/Video/W02953T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 21: ['W00357B.mp4', 'W00357N.mp4', 'W00357T.mp4']
# Đang xử lý video: W00357B.mp4
# ✔ Giữ 64 khung, loại 2 khung – video lưu: data/Video/W00357B.mp4
# Video đã lưu tại: data/Video/W00357B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00357N.mp4
# ✔ Giữ 40 khung, loại 44 khung – video lưu: data/Video/W00357N.mp4
# Video đã lưu tại: data/Video/W00357N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00357T.mp4
# ✔ Giữ 40 khung, loại 44 khung – video lưu: data/Video/W00357T.mp4
# Video đã lưu tại: data/Video/W00357T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 22: ['W03042B.mp4', 'W03042N.mp4', 'W03042T.mp4']
# Đang xử lý video: W03042B.mp4
# ✔ Giữ 69 khung, loại 50 khung – video lưu: data/Video/W03042B.mp4
# Video đã lưu tại: data/Video/W03042B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03042N.mp4
# ✔ Giữ 115 khung, loại 6 khung – video lưu: data/Video/W03042N.mp4
# Video đã lưu tại: data/Video/W03042N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03042T.mp4
# ✔ Giữ 68 khung, loại 51 khung – video lưu: data/Video/W03042T.mp4
# Video đã lưu tại: data/Video/W03042T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 23: ['W03071B.mp4', 'W03071N.mp4', 'W03071T.mp4']
# Đang xử lý video: W03071B.mp4
# ✔ Giữ 49 khung, loại 34 khung – video lưu: data/Video/W03071B.mp4
# Video đã lưu tại: data/Video/W03071B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03071N.mp4
# ✔ Giữ 78 khung, loại 42 khung – video lưu: data/Video/W03071N.mp4
# Video đã lưu tại: data/Video/W03071N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03071T.mp4
# ✔ Giữ 96 khung, loại 24 khung – video lưu: data/Video/W03071T.mp4
# Video đã lưu tại: data/Video/W03071T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 24: ['W00274N.mp4', 'W00274B.mp4', 'W00274T.mp4']
# Đang xử lý video: W00274N.mp4
# ✔ Giữ 69 khung, loại 71 khung – video lưu: data/Video/W00274N.mp4
# Video đã lưu tại: data/Video/W00274N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00274B.mp4
# ✔ Giữ 65 khung, loại 90 khung – video lưu: data/Video/W00274B.mp4
# Video đã lưu tại: data/Video/W00274B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00274T.mp4
# ✔ Giữ 65 khung, loại 90 khung – video lưu: data/Video/W00274T.mp4
# Video đã lưu tại: data/Video/W00274T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 25: ['W03138N.mp4', 'W03138T.mp4', 'W03138B.mp4']
# Đang xử lý video: W03138N.mp4
# ✔ Giữ 63 khung, loại 14 khung – video lưu: data/Video/W03138N.mp4
# Video đã lưu tại: data/Video/W03138N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03138T.mp4
# ✔ Giữ 58 khung, loại 55 khung – video lưu: data/Video/W03138T.mp4
# Video đã lưu tại: data/Video/W03138T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03138B.mp4
# ✔ Giữ 72 khung, loại 141 khung – video lưu: data/Video/W03138B.mp4
# Video đã lưu tại: data/Video/W03138B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 26: ['W03197T.mp4', 'W03197N.mp4', 'W03197B.mp4']
# Đang xử lý video: W03197T.mp4
# ✔ Giữ 43 khung, loại 85 khung – video lưu: data/Video/W03197T.mp4
# Video đã lưu tại: data/Video/W03197T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03197N.mp4
# ✔ Giữ 48 khung, loại 44 khung – video lưu: data/Video/W03197N.mp4
# Video đã lưu tại: data/Video/W03197N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03197B.mp4
# ✔ Giữ 128 khung, loại 0 khung – video lưu: data/Video/W03197B.mp4
# Video đã lưu tại: data/Video/W03197B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 27: ['W00159N.mp4', 'W00159B.mp4', 'W00159T.mp4']
# Đang xử lý video: W00159N.mp4
# ✔ Giữ 74 khung, loại 90 khung – video lưu: data/Video/W00159N.mp4
# Video đã lưu tại: data/Video/W00159N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00159B.mp4
# ✔ Giữ 91 khung, loại 61 khung – video lưu: data/Video/W00159B.mp4
# Video đã lưu tại: data/Video/W00159B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00159T.mp4
# ✔ Giữ 73 khung, loại 91 khung – video lưu: data/Video/W00159T.mp4
# Video đã lưu tại: data/Video/W00159T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 28: ['W03156T.mp4', 'W03156B.mp4', 'W03156N.mp4']
# Đang xử lý video: W03156T.mp4
# ✔ Giữ 73 khung, loại 35 khung – video lưu: data/Video/W03156T.mp4
# Video đã lưu tại: data/Video/W03156T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03156B.mp4
# ✔ Giữ 131 khung, loại 2 khung – video lưu: data/Video/W03156B.mp4
# Video đã lưu tại: data/Video/W03156B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03156N.mp4
# ✔ Giữ 77 khung, loại 31 khung – video lưu: data/Video/W03156N.mp4
# Video đã lưu tại: data/Video/W03156N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 29: ['W03167B.mp4', 'W03167T.mp4', 'W03167N.mp4']
# Đang xử lý video: W03167B.mp4
# ✔ Giữ 100 khung, loại 0 khung – video lưu: data/Video/W03167B.mp4
# Video đã lưu tại: data/Video/W03167B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03167T.mp4
# ✔ Giữ 79 khung, loại 28 khung – video lưu: data/Video/W03167T.mp4
# Video đã lưu tại: data/Video/W03167T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03167N.mp4
# ✔ Giữ 76 khung, loại 31 khung – video lưu: data/Video/W03167N.mp4
# Video đã lưu tại: data/Video/W03167N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 30: ['W03153B.mp4', 'W03153N.mp4', 'W03153T.mp4']
# Đang xử lý video: W03153B.mp4
# ✔ Giữ 52 khung, loại 79 khung – video lưu: data/Video/W03153B.mp4
# Video đã lưu tại: data/Video/W03153B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03153N.mp4
# ✔ Giữ 81 khung, loại 10 khung – video lưu: data/Video/W03153N.mp4
# Video đã lưu tại: data/Video/W03153N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03153T.mp4
# ✔ Giữ 66 khung, loại 25 khung – video lưu: data/Video/W03153T.mp4
# Video đã lưu tại: data/Video/W03153T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 31: ['W03148T.mp4', 'W03148N.mp4', 'W03148B.mp4']
# Đang xử lý video: W03148T.mp4
# ✔ Giữ 66 khung, loại 9 khung – video lưu: data/Video/W03148T.mp4
# Video đã lưu tại: data/Video/W03148T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03148N.mp4
# ✔ Giữ 67 khung, loại 8 khung – video lưu: data/Video/W03148N.mp4
# Video đã lưu tại: data/Video/W03148N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03148B.mp4
# ✔ Giữ 217 khung, loại 0 khung – video lưu: data/Video/W03148B.mp4
# Video đã lưu tại: data/Video/W03148B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 32: ['W00186N.mp4', 'W00186T.mp4', 'W00186B.mp4']
# Đang xử lý video: W00186N.mp4
# ✔ Giữ 45 khung, loại 82 khung – video lưu: data/Video/W00186N.mp4
# Video đã lưu tại: data/Video/W00186N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00186T.mp4
# ✔ Giữ 45 khung, loại 82 khung – video lưu: data/Video/W00186T.mp4
# Video đã lưu tại: data/Video/W00186T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00186B.mp4
# ✔ Giữ 55 khung, loại 84 khung – video lưu: data/Video/W00186B.mp4
# Video đã lưu tại: data/Video/W00186B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 33: ['W00196B.mp4', 'W00196T.mp4', 'W00196N.mp4']
# Đang xử lý video: W00196B.mp4
# ✔ Giữ 49 khung, loại 53 khung – video lưu: data/Video/W00196B.mp4
# Video đã lưu tại: data/Video/W00196B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00196T.mp4
# ✔ Giữ 52 khung, loại 48 khung – video lưu: data/Video/W00196T.mp4
# Video đã lưu tại: data/Video/W00196T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00196N.mp4
# ✔ Giữ 50 khung, loại 50 khung – video lưu: data/Video/W00196N.mp4
# Video đã lưu tại: data/Video/W00196N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 34: ['W00255B.mp4', 'W00255N.mp4', 'W00255T.mp4']
# Đang xử lý video: W00255B.mp4
# ✔ Giữ 68 khung, loại 68 khung – video lưu: data/Video/W00255B.mp4
# Video đã lưu tại: data/Video/W00255B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00255N.mp4
# ✔ Giữ 62 khung, loại 86 khung – video lưu: data/Video/W00255N.mp4
# Video đã lưu tại: data/Video/W00255N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00255T.mp4
# ✔ Giữ 134 khung, loại 58 khung – video lưu: data/Video/W00255T.mp4
# Video đã lưu tại: data/Video/W00255T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 35: ['W00198.mp4', 'W00198N.mp4', 'W00198B.mp4']
# Đang xử lý video: W00198.mp4
# ✔ Giữ 103 khung, loại 27 khung – video lưu: data/Video/W00198.mp4
# Video đã lưu tại: data/Video/W00198.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00198N.mp4
# ✔ Giữ 53 khung, loại 58 khung – video lưu: data/Video/W00198N.mp4
# Video đã lưu tại: data/Video/W00198N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00198B.mp4
# ✔ Giữ 58 khung, loại 90 khung – video lưu: data/Video/W00198B.mp4
# Video đã lưu tại: data/Video/W00198B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 36: ['W03134T.mp4', 'W03134N.mp4', 'W03134B.mp4']
# Đang xử lý video: W03134T.mp4
# ✔ Giữ 80 khung, loại 5 khung – video lưu: data/Video/W03134T.mp4
# Video đã lưu tại: data/Video/W03134T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03134N.mp4
# ✔ Giữ 77 khung, loại 8 khung – video lưu: data/Video/W03134N.mp4
# Video đã lưu tại: data/Video/W03134N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03134B.mp4
# ✔ Giữ 107 khung, loại 0 khung – video lưu: data/Video/W03134B.mp4
# Video đã lưu tại: data/Video/W03134B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 37: ['W00216T.mp4', 'W00216B.mp4', 'W00216N.mp4']
# Đang xử lý video: W00216T.mp4
# ✔ Giữ 124 khung, loại 0 khung – video lưu: data/Video/W00216T.mp4
# Video đã lưu tại: data/Video/W00216T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00216B.mp4
# ✔ Giữ 129 khung, loại 2 khung – video lưu: data/Video/W00216B.mp4
# Video đã lưu tại: data/Video/W00216B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00216N.mp4
# ✔ Giữ 124 khung, loại 0 khung – video lưu: data/Video/W00216N.mp4
# Video đã lưu tại: data/Video/W00216N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 38: ['W00220B.mp4', 'W00220N.mp4', 'W00220T.mp4']
# Đang xử lý video: W00220B.mp4
# ✔ Giữ 63 khung, loại 71 khung – video lưu: data/Video/W00220B.mp4
# Video đã lưu tại: data/Video/W00220B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00220N.mp4
# ✔ Giữ 58 khung, loại 58 khung – video lưu: data/Video/W00220N.mp4
# Video đã lưu tại: data/Video/W00220N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00220T.mp4
# ✔ Giữ 66 khung, loại 68 khung – video lưu: data/Video/W00220T.mp4
# Video đã lưu tại: data/Video/W00220T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 39: ['W03105N.mp4', 'W03105B.mp4', 'W03105T.mp4']
# Đang xử lý video: W03105N.mp4
# ✔ Giữ 76 khung, loại 20 khung – video lưu: data/Video/W03105N.mp4
# Video đã lưu tại: data/Video/W03105N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03105B.mp4
# ✔ Giữ 134 khung, loại 2 khung – video lưu: data/Video/W03105B.mp4
# Video đã lưu tại: data/Video/W03105B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03105T.mp4
# ✔ Giữ 122 khung, loại 14 khung – video lưu: data/Video/W03105T.mp4
# Video đã lưu tại: data/Video/W03105T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 40: ['W03085N.mp4', 'W03085B.mp4', 'W03085T.mp4']
# Đang xử lý video: W03085N.mp4
# ✔ Giữ 67 khung, loại 24 khung – video lưu: data/Video/W03085N.mp4
# Video đã lưu tại: data/Video/W03085N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03085B.mp4
# ✔ Giữ 89 khung, loại 3 khung – video lưu: data/Video/W03085B.mp4
# Video đã lưu tại: data/Video/W03085B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W03085T.mp4
# ✔ Giữ 184 khung, loại 0 khung – video lưu: data/Video/W03085T.mp4
# Video đã lưu tại: data/Video/W03085T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 41: ['W00359N.mp4', 'W00359T.mp4', 'W00359B.mp4']
# Đang xử lý video: W00359N.mp4
# ✔ Giữ 75 khung, loại 45 khung – video lưu: data/Video/W00359N.mp4
# Video đã lưu tại: data/Video/W00359N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00359T.mp4
# ✔ Giữ 118 khung, loại 0 khung – video lưu: data/Video/W00359T.mp4
# Video đã lưu tại: data/Video/W00359T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00359B.mp4
# ✔ Giữ 118 khung, loại 0 khung – video lưu: data/Video/W00359B.mp4
# Video đã lưu tại: data/Video/W00359B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 42: ['W00368B.mp4', 'W00368T.mp4', 'W00368N.mp4']
# Đang xử lý video: W00368B.mp4
# ✔ Giữ 57 khung, loại 72 khung – video lưu: data/Video/W00368B.mp4
# Video đã lưu tại: data/Video/W00368B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00368T.mp4
# ✔ Giữ 62 khung, loại 90 khung – video lưu: data/Video/W00368T.mp4
# Video đã lưu tại: data/Video/W00368T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00368N.mp4
# ✔ Giữ 63 khung, loại 89 khung – video lưu: data/Video/W00368N.mp4
# Video đã lưu tại: data/Video/W00368N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 43: ['W00367B.mp4', 'W00367T.mp4', 'W00367N.mp4']
# Đang xử lý video: W00367B.mp4
# ✔ Giữ 63 khung, loại 52 khung – video lưu: data/Video/W00367B.mp4
# Video đã lưu tại: data/Video/W00367B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00367T.mp4
# ✔ Giữ 45 khung, loại 40 khung – video lưu: data/Video/W00367T.mp4
# Video đã lưu tại: data/Video/W00367T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00367N.mp4
# ✔ Giữ 45 khung, loại 40 khung – video lưu: data/Video/W00367N.mp4
# Video đã lưu tại: data/Video/W00367N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 44: ['W00484T.mp4', 'W00484B.mp4', 'W00484N.mp4']
# Đang xử lý video: W00484T.mp4
# ✔ Giữ 152 khung, loại 0 khung – video lưu: data/Video/W00484T.mp4
# Video đã lưu tại: data/Video/W00484T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00484B.mp4
# ✔ Giữ 152 khung, loại 0 khung – video lưu: data/Video/W00484B.mp4
# Video đã lưu tại: data/Video/W00484B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00484N.mp4
# ✔ Giữ 67 khung, loại 73 khung – video lưu: data/Video/W00484N.mp4
# Video đã lưu tại: data/Video/W00484N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 45: ['W02825B.mp4', 'W02825T.mp4', 'W02825N.mp4']
# Đang xử lý video: W02825B.mp4
# ✔ Giữ 45 khung, loại 49 khung – video lưu: data/Video/W02825B.mp4
# Video đã lưu tại: data/Video/W02825B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02825T.mp4
# ✔ Giữ 35 khung, loại 41 khung – video lưu: data/Video/W02825T.mp4
# Video đã lưu tại: data/Video/W02825T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02825N.mp4
# ✔ Giữ 35 khung, loại 41 khung – video lưu: data/Video/W02825N.mp4
# Video đã lưu tại: data/Video/W02825N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 46: ['W02818T.mp4', 'W02818B.mp4', 'W02818N.mp4']
# Đang xử lý video: W02818T.mp4
# ✔ Giữ 66 khung, loại 6 khung – video lưu: data/Video/W02818T.mp4
# Video đã lưu tại: data/Video/W02818T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02818B.mp4
# ✔ Giữ 79 khung, loại 0 khung – video lưu: data/Video/W02818B.mp4
# Video đã lưu tại: data/Video/W02818B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02818N.mp4
# ✔ Giữ 66 khung, loại 6 khung – video lưu: data/Video/W02818N.mp4
# Video đã lưu tại: data/Video/W02818N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 47: ['W02813B.mp4', 'W02813N.mp4', 'W02813T.mp4']
# Đang xử lý video: W02813B.mp4
# ✔ Giữ 92 khung, loại 0 khung – video lưu: data/Video/W02813B.mp4
# Video đã lưu tại: data/Video/W02813B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02813N.mp4
# ✔ Giữ 43 khung, loại 45 khung – video lưu: data/Video/W02813N.mp4
# Video đã lưu tại: data/Video/W02813N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02813T.mp4
# ✔ Giữ 82 khung, loại 10 khung – video lưu: data/Video/W02813T.mp4
# Video đã lưu tại: data/Video/W02813T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 48: ['W02814N.mp4', 'W02814T.mp4', 'W02814B.mp4']
# Đang xử lý video: W02814N.mp4
# ✔ Giữ 63 khung, loại 35 khung – video lưu: data/Video/W02814N.mp4
# Video đã lưu tại: data/Video/W02814N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02814T.mp4
# ✔ Giữ 91 khung, loại 1 khung – video lưu: data/Video/W02814T.mp4
# Video đã lưu tại: data/Video/W02814T.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W02814B.mp4
# ✔ Giữ 50 khung, loại 42 khung – video lưu: data/Video/W02814B.mp4
# Video đã lưu tại: data/Video/W02814B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video gloss 49: ['W00493B.mp4', 'W00493N.mp4', 'W00493T.mp4']
# Đang xử lý video: W00493B.mp4
# ✔ Giữ 183 khung, loại 115 khung – video lưu: data/Video/W00493B.mp4
# Video đã lưu tại: data/Video/W00493B.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00493N.mp4
# ✔ Giữ 100 khung, loại 154 khung – video lưu: data/Video/W00493N.mp4
# Video đã lưu tại: data/Video/W00493N.mp4
# --------------------------------------------------
#
#
# Đang xử lý video: W00493T.mp4
# ✔ Giữ 99 khung, loại 155 khung – video lưu: data/Video/W00493T.mp4
# Video đã lưu tại: data/Video/W00493T.mp4
# --------------------------------------------------
#
#
# 0 video không giữ khung nào: []

# %%
df_video.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
